# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as spy
import networkx as nx
from   sklearn.datasets import make_s_curve
import seaborn as sns
import time
import pickle

# %%
import networkx as nx
import faiss
import time
import scipy as spy
from datasketch import MinHash
from scipy.optimize import curve_fit
import statsmodels.api as sm
import copy


def Random_Fourier_Feature_Hashing(X,TargetDim):
    N = np.size(X,0)
    d = np.size(X,1)
    W = np.random.normal(loc=0, scale=1, size=(d, TargetDim))
    b = np.random.uniform(0, 2*np.pi, size=TargetDim)
    B = np.repeat(b[:, np.newaxis], N, axis=1).T
    Z = 1/2* (1+ np.sign(np.cos(X @ W + B)))
    Z = np.uint8(Z)
    return Z

def Random_Cauchy_Feature_Hashing(X,TargetDim):
    N = np.size(X,0)
    d = np.size(X,1)
    W = spy.stats.cauchy.rvs(loc=0, scale=1, size=(d, TargetDim))
    b = np.random.uniform(0, 2*np.pi, size=TargetDim)
    B = np.repeat(b[:, np.newaxis], N, axis=1).T
    Z = 1/2* (1+ np.sign(np.cos(X @ W + B)))
    Z = np.uint8(Z)
    return Z

def Random_Hyperplane_Hashing(X,TargetDim):
    d = np.size(X,1)
    W = np.random.normal(loc=0, scale=1, size=(d, TargetDim))
    Z = 1/2* (1+ np.sign(X @ W))
    Z = np.uint8(Z)
    return Z

def Random_Min_Hashing(X,TargetDim):
    Z=np.zeros((len(X),TargetDim))
    for ID1 in range(len(X)):
        Hashing_Code=MinHash(num_perm=TargetDim)
        Hashing_Code.update_batch(X[ID1])
        Z[ID1,:]=Hashing_Code.hashvalues
    return Z

def Neighbor_Generator(X,UnitNum):
    Y=[]
    for Unit in range(UnitNum):
        Neighbors = [Unit] + list(X.neighbors(Unit))
        Y.append(np.array(Neighbors))
    return Y


def Normalization_Function(X_Current,Method_Type):
    if Method_Type=="Linear_Kernel":
        Normalized_X=X_Current-np.mean(X_Current,axis=1).reshape(np.size(X_Current,0),1)
    elif Method_Type=="Gaussian_Kernel":
        Normalized_X=X_Current-np.mean(X_Current,axis=1).reshape(np.size(X_Current,0),1)
        Std=np.std(Normalized_X,axis=1).reshape(np.size(Normalized_X,0),1)
        Normalized_X=np.divide(Normalized_X,Std,out=Normalized_X,where=Std!=0)
    elif Method_Type=="Cauchy_Kernel":
        Normalized_X=X_Current-np.min(X_Current,axis=1).reshape(np.size(X_Current,0),1)
        SumV=np.sum(Normalized_X,axis=1).reshape(np.size(Normalized_X,0),1)
        Normalized_X=np.divide(Normalized_X,SumV,out=Normalized_X,where=SumV!=0)
    return Normalized_X

def Binary_Hashing_Index(Z):
    if np.size(Z,0)<=50000:
        Dim=8*np.size(Z,1)
        Index = faiss.IndexBinaryFlat(Dim)
        Index.nprobe = 2
    elif (np.size(Z,0)>50000)&(np.size(Z,0)<=500000):
        Dim=8*np.size(Z,1)
        Index = faiss.IndexBinaryHash(Dim,Dim)
        Index.nprobe = 2
    elif np.size(Z,0)>500000:
        Dim=8*np.size(Z,1)
        Index = faiss.IndexBinaryHash(Dim,int(np.max([np.min([np.ceil(Dim/100),32]),16])))
        Index.nprobe = 2
    return Index


def KNN_with_Hashing_Index(Z):
    StartT=time.time()
    Index=Binary_Hashing_Index(Z)
    Index.add(Z)
    Num_neighbors=2
    D, I = Index.search(Z, Num_neighbors)
    EndT=time.time()
    print(['KNN search costs-', EndT-StartT])
    return D,I

def Hashing_Function(Normalized_X,TargetDim,Method_Type):
    if Method_Type=="Linear_Kernel":
        Z=Random_Hyperplane_Hashing(Normalized_X,TargetDim)
    elif Method_Type=="Gaussian_Kernel":
        Z=Random_Fourier_Feature_Hashing(Normalized_X,TargetDim)
    elif Method_Type=="Cauchy_Kernel":
        Z=Random_Cauchy_Feature_Hashing(Normalized_X,TargetDim)
    return Z

def Renormalization_Function(X_Current,TargetDim,Iter,Method_Type):
    Normalized_X=Normalization_Function(X_Current,Method_Type)
    Z=Hashing_Function(Normalized_X,TargetDim,Method_Type)
    _,I=KNN_with_Hashing_Index(Z)
    G = nx.empty_graph(np.size(I,0))
    Edge = np.vstack((np.arange(0, np.size(I, 0)), I[:,1])).T
    G.add_edges_from(Edge)
    Clusters=[list(c) for c in list(nx.connected_components(G))]
    ClusterNum=nx.number_connected_components(G)
    print(['There are', ClusterNum, 'macro-units after', Iter+1, 'times of renormalization'])
    X_New=np.zeros((ClusterNum, np.size(X_Current,1)))
    Corase_ID = []
    for ID1 in range(ClusterNum):
        X_New[ID1,:]=np.sum(X_Current[Clusters[ID1],:],axis=0)
        Corase_ID.append(Clusters[ID1])
    return X_New, Corase_ID

def Network_Renormalization_Function(X_Current,TargetDim,Iter,Method_Type): 
    UnitNum=nx.number_of_nodes(X_Current)
    Y=Neighbor_Generator(X_Current,UnitNum)
    Z=Random_Min_Hashing(Y,TargetDim)
    Z=Hashing_Function(Z,TargetDim,Method_Type)
    _,I=KNN_with_Hashing_Index(Z)
    G = nx.empty_graph(np.size(I,0))
    Edge = np.vstack((np.arange(0, np.size(I, 0)), I[:,1])).T

    G.add_edges_from(Edge)
    Potential_Clusters=[list(c) for c in list(nx.connected_components(G))]
    Potential_ClusterNum=nx.number_connected_components(G)
    Edge_To_Remove=[]
    for ID1 in range(Potential_ClusterNum):
        Unit_list=Potential_Clusters[ID1]
        if len(Unit_list)>1:
            H = nx.induced_subgraph(X_Current,Unit_list)
            Potential_H = nx.induced_subgraph(G,Unit_list)
            Wrong_Edge=list(set(list(Potential_H.edges))-set(list(H.edges)))
            Edge_To_Remove.extend(Wrong_Edge)

    for Wrong_Edge in Edge_To_Remove:
        G.remove_edge(*Wrong_Edge)

    Clusters=[list(c) for c in list(nx.connected_components(G))]
    ClusterNum=nx.number_connected_components(G)
    print(['There are', ClusterNum, 'macro-units after', Iter+1, 'times of renormalization'])


    X_New=copy.deepcopy(X_Current)
    Pre_Corase_ID = []
    Mappings={}
    for ID1 in range(ClusterNum):
        Unit_list=Clusters[ID1]
        Pre_Corase_ID.append(Unit_list)
        Unit0 = Unit_list[0]
        Mappings[Unit0]=ID1
        for Unit in Unit_list[1:]:
            if X_New.has_node(Unit):
                Neighbors = list(X_New.neighbors(Unit))
                New_edges = [(Unit0, Nei) for Nei in Neighbors if Unit0!=Nei]
                X_New.add_edges_from(New_edges)
                X_New.remove_node(Unit)
    Corase_ID = []
    Unit_Mappings={}
    for ID_1,ID_2 in enumerate(X_New.nodes()):
        Unit_Mappings[ID_2]=ID_1
        Corase_ID.append(Pre_Corase_ID[Mappings[ID_2]])
    X_New = nx.relabel_nodes(X_New, Unit_Mappings)
    
    return X_New, Corase_ID

def Tracking_System(Corase_ID_list):
    Tracked_ID_list = []
    for IterID in range(len(Corase_ID_list)):
        if IterID==0:
            Tracked_ID_list.append(Corase_ID_list[0])
        else:
            Tracked_ID = []
            if len(Corase_ID_list[IterID])>0:
                for CoarseID in range(len(Corase_ID_list[IterID])):
                    UnitsToTrack=Corase_ID_list[IterID][CoarseID]
                    Searched_ID=[]
                    for IDSearch in range(len(UnitsToTrack)):
                        Search_ID=1
                        while len(Tracked_ID_list[IterID-Search_ID])==0:
                            Search_ID=Search_ID+1
                        Searched_ID=Searched_ID+Tracked_ID_list[IterID-Search_ID][UnitsToTrack[IDSearch]]
                    Tracked_ID.append(Searched_ID)
            Tracked_ID_list.append(Tracked_ID)
    return Tracked_ID_list

def Renormalization_Flow(X_Initial,Iteration_Num,TargetDim,Method_Type,Data_Type):
    RG_Flow=[]
    RG_Flow.append(X_Initial)
    Corase_ID_list=[]
    for Iter in range(Iteration_Num):
        StartT=time.time()
        X_Current=RG_Flow[Iter]
        if Data_Type=="Dynamics":
            X_New, Corase_ID=Renormalization_Function(X_Current,TargetDim,Iter,Method_Type)
        elif Data_Type=="Structure":
            X_New, Corase_ID=Network_Renormalization_Function(X_Current,TargetDim,Iter,Method_Type)
            if nx.number_of_edges(X_New)==0:
                break
        RG_Flow.append(X_New)
        Corase_ID_list.append(Corase_ID)
        EndT=time.time()
        print(['The', Iter+1, 'time of renormalization costs-', EndT-StartT])
    Tracked_ID_list=Tracking_System(Corase_ID_list)
    return RG_Flow,Tracked_ID_list


## Analysis 
def Linear_func(x, a, b):
    return b*x+a

def Power_func(x, a):
    return a*x


def RSquareFun(X,y,popt):
    if len(popt)==2:
        pre_y = Linear_func(X, popt[0], popt[1])
    elif len(popt)==1:
        pre_y = Power_func(X, popt[0])
    mean = np.mean(y)  
    ss_tot = np.sum((y - mean) ** 2)  
    ss_res = np.sum((y - pre_y) ** 2)  
    r_squared = 1 - (ss_res / ss_tot)

    mse = np.sum((y - pre_y) ** 2)/ len(y)
    return r_squared, mse

def Alpha_Scaling(RG_Flow,Tracked_ID_list):
    MeanVar=np.zeros(len(RG_Flow))
    for Iter in range(len(RG_Flow)):
        X=RG_Flow[Iter]
        MeanVar[Iter]=np.mean(np.var(X,axis=1))
    
    MeanClusterSize=np.ones(len(RG_Flow))
    for Iter in range(len(Tracked_ID_list)):
        ClusterSize=[len(IDC) for IDC in Tracked_ID_list[Iter]]
        MeanClusterSize[Iter+1]=np.mean(ClusterSize)

    popt, _ = curve_fit(Linear_func, np.log(MeanClusterSize), np.log(MeanVar))
    Coeff = popt[0]
    Alpha = popt[1]
    R2, MSE= RSquareFun(np.log(MeanClusterSize), np.log(MeanVar), popt)
    Esti_Alpha_Scaling=np.exp(Coeff)*np.power(MeanClusterSize,Alpha)
    return MeanClusterSize, MeanVar, Coeff, Alpha, R2, MSE, Esti_Alpha_Scaling

def Beta_Scaling(RG_Flow,Tracked_ID_list):
    FreeEV=np.zeros(len(RG_Flow))
    for Iter in range(len(RG_Flow)):
        X=RG_Flow[Iter]

        P_SilenceV=np.zeros(np.size(X,0))
        for ID1 in range(np.size(X,0)):
            P_SilenceV[ID1] = 1-np.count_nonzero(X[ID1,:]) / np.size(X,1)
        P_Silence=np.mean(P_SilenceV)
        FreeEV[Iter]=-1*np.log(P_Silence)

    MeanClusterSize=np.ones(len(RG_Flow))
    for Iter in range(len(Tracked_ID_list)):
        ClusterSize=[len(IDC) for IDC in Tracked_ID_list[Iter]]
        MeanClusterSize[Iter+1]=np.mean(ClusterSize)

    Needed=np.where(np.isinf(FreeEV)==0)[0]
    FreeEV=FreeEV[Needed]
    MeanClusterSize=MeanClusterSize[Needed]

    popt, _ = curve_fit(Linear_func, np.log(MeanClusterSize), np.log(FreeEV))
    Coeff = popt[0]
    Beta = popt[1]
    R2, MSE= RSquareFun(np.log(MeanClusterSize), np.log(FreeEV), popt)
    Esti_Beta_Scaling=np.exp(Coeff)*np.power(MeanClusterSize,Beta)
    return MeanClusterSize, FreeEV, Coeff, Beta, R2, MSE, Esti_Beta_Scaling

def Mu_Scaling(RG_Flow,Tracked_ID_list):
    Initial_X = RG_Flow[0]
    Average_Rank_K=[]
    Average_Evals=[]

    ClusterNum=np.array([len(Tracked_ID_list[ID1]) for ID1 in range(1,len(Tracked_ID_list))])
    Max_Range=np.max(np.where(ClusterNum>1)[0])+2
    for ID1 in range(1,Max_Range):
        x=[]
        y=[]
        for ID2 in range(len(Tracked_ID_list[ID1])):
            WithinCluster= Tracked_ID_list[ID1][ID2]
            X_WC = Initial_X[WithinCluster,:]
            X_WC=X_WC-np.mean(X_WC,axis=1).reshape(np.size(X_WC,0),1)
            Cov=np.cov(X_WC)
            Evals, _ = np.linalg.eig(Cov)
            Evals = np.sort(np.real(Evals))
            Evals = Evals[::-1]
            
            Rank = np.cumsum(np.ones(len(Evals)))
            Rank_K=Rank/len(WithinCluster)
        
            Needed_Loc=np.where(Evals>0)[0]
            Rank_K=Rank_K[Needed_Loc]
            Evals=Evals[Needed_Loc]
            x.extend(Rank_K[:]) 
            y.extend(Evals[:])

        _, bins = np.histogram(x)
        Meanx=np.zeros(len(bins)-1)
        Meany=np.zeros(len(bins)-1)
        for ID3 in range(len(bins)-1):
            Neededx=np.where((x>=bins[ID3])&(x<=bins[ID3+1]))[0]
            Meanx[ID3]=np.mean(np.array(x)[Neededx])
            Meany[ID3]=np.mean(np.array(y)[Neededx])
        Average_Rank_K.extend(Meanx)
        Average_Evals.extend(Meany)
    
    popt, _ = curve_fit(Linear_func, np.log(Average_Rank_K), np.log(Average_Evals))
    Coeff = popt[0]
    Mu = -1* popt[1]
    R2, MSE= RSquareFun(np.log(Average_Rank_K), np.log(Average_Evals), popt)
    Esti_Mu_Scaling=np.exp(Coeff)*np.power(Average_Rank_K,-1* Mu)
    return Average_Rank_K, Average_Evals, Coeff, Mu, R2, MSE, Esti_Mu_Scaling

def Theta_Scaling(RG_Flow,Tracked_ID_list):
    Tau=np.zeros(len(RG_Flow))
    ScaledT=[]
    MeanACFs=[]

    for Iter in range(len(RG_Flow)):
        X=RG_Flow[Iter]
        SumAC = np.sum(X, axis=1)

        ACFMatrix = np.zeros_like(X)
        for ID1 in range(np.size(X,0)):
            ACFMatrix[ID1,:] = sm.tsa.acf(X[ID1,:], nlags=np.size(X,1))
        ACFMatrix = ACFMatrix[np.where(SumAC>0)[0],:]
        MeanACF = np.mean(ACFMatrix, axis=0)
        T = np.cumsum(np.ones(np.size(X,1)))-1

        Needed_ACF=np.where(MeanACF>0)[0]
        MeanACF=MeanACF[Needed_ACF]
        T=T[Needed_ACF]

        Cut_Off=int(np.max([np.ceil(0.01*len(T)),100]))
        popt, _ = curve_fit(Power_func, T[:Cut_Off], np.log(MeanACF[:Cut_Off]))
        Tau[Iter] = -1/popt[0]

        ScaledT.append(T/Tau[Iter])
        MeanACFs.append(MeanACF)
    
    MeanClusterSize=np.ones(len(RG_Flow))
    for Iter in range(len(Tracked_ID_list)):
        ClusterSize=[len(IDC) for IDC in Tracked_ID_list[Iter]]
        MeanClusterSize[Iter+1]=np.mean(ClusterSize)
    
    popt, _ = curve_fit(Linear_func, np.log(MeanClusterSize), np.log(Tau))
    Coeff = popt[0]
    Theta = popt[1]
    R2, MSE= RSquareFun(np.log(MeanClusterSize), np.log(Tau), popt)
    Esti_Theta_Scaling=np.exp(Coeff)*np.power(MeanClusterSize,Theta)

    return ScaledT, MeanACFs, MeanClusterSize, Tau, Coeff, Theta, R2, MSE, Esti_Theta_Scaling

def KS_Analysis(RG_Flow):
    K_S_Static=np.zeros(len(RG_Flow))
    Degrees_O=[Node[1] for Node in list(nx.degree(RG_Flow[0]))]
    for InterID in range(len(RG_Flow)):
        print([InterID,PathType])
        Normalization=(nx.number_of_nodes(RG_Flow[InterID])-1)*nx.number_of_nodes(RG_Flow[InterID])/2
        Degrees=[Node[1] for Node in list(nx.degree(RG_Flow[InterID]))]
        KstestResult=ks_2samp(Degrees, Degrees_O, alternative='two-sided',method='exact')
        K_S_Static[InterID]=KstestResult[0]*(KstestResult[1]<0.01)

    Mean_K_S_Static=np.mean(K_S_Static)
    return Mean_K_S_Static

def Normalized_Dynamics(RG_Flow,Tracked_ID_list,Cut_Off_Ratio):
    ClusterNum=np.array([len(Tracked_ID_list[ID1]) for ID1 in range(1,len(Tracked_ID_list))])
    Max_Range=np.max(np.where(ClusterNum>1)[0])+1
    for IterID in range(Max_Range):
        X_Current=RG_Flow[IterID]
        N=np.size(X_Current,0)
        Covariance = np.cov(X_Current)
        Evals, U = np.linalg.eig(Covariance)
        Idx = Evals.argsort()[::-1]
        EigenValues = Evals[Idx]
        EigenVectors = U[:,Idx]
        k=np.round(N*Cut_Off_Ratio)
        P=EigenVectors[:,:k] @ EigenVectors[:,:k].T
        phi=P@(X_Current-np.mean(X_Current,axis=1,keepdims=True))
        Normalized_activity=phi/np.std(phi,axis=1,keepdims=True)
    return Normalized_activity

# %%
X_Initial = np.random.randn(10000, 5000)

RG_Flow,Tracked_ID_list=Renormalization_Flow(X_Initial,100,100,"Linear_Kernel","Dynamics")
# Out:
# ['KNN search costs-', 0.0]
# ['There are', 199, 'macro-units after', 1, 'times of renormalization']
# ['The', 1, 'time of renormalization costs-', 0.1575779914855957]
# ['KNN search costs-', 0.0]
# ['There are', 197, 'macro-units after', 2, 'times of renormalization']
# ['The', 2, 'time of renormalization costs-', 0.20046615600585938]
# ['KNN search costs-', 0.0]
# ['There are', 195, 'macro-units after', 3, 'times of renormalization']
# ['The', 3, 'time of renormalization costs-', 0.2175588607788086]
# ['KNN search costs-', 0.001993894577026367]
# ['There are', 191, 'macro-units after', 4, 'times of renormalization']
# ['The', 4, 'time of renormalization costs-', 0.2812538146972656]
# ['KNN search costs-', 0.0009980201721191406]
# ['There are', 188, 'macro-units after', 5, 'times of renormalization']
# ['The', 5, 'time of renormalization costs-', 0.1994614601135254]
# ['KNN search costs-', 0.0]
# ['There are', 187, 'macro-units after', 6, 'times of renormalization']
# ['The', 6, 'time of renormalization costs-', 0.20745325088500977]
# ['KNN search costs-', 0.0]
# ['There are', 186, 'macro-units after', 7, 'times of renormalization']
# ['The', 7, 'time of renormalization costs-', 0.18510770797729492]
# ['KNN search costs-', 0.0]
# ['There are', 185, 'macro-units after', 8, 'times of renormalization']
# ['The', 8, 'time of renormalization costs-', 0.18983054161071777]
# ['KNN search costs-', 0.0]
# ['There are', 185, 'macro-units after', 9, 'times of renormalization']
# ['The', 9, 'time of renormalization costs-', 0.21841955184936523]
# ['KNN search costs-', 0.0]
# ['There are', 184, 'macro-units after', 10, 'times of renormalization']
# ['The', 10, 'time of renormalization costs-', 0.17752313613891602]
# ['KNN search costs-', 0.0]
# ['There are', 184, 'macro-units after', 11, 'times of renormalization']
# ['The', 11, 'time of renormalization costs-', 0.2014620304107666]
# ['KNN search costs-', 0.0010004043579101562]
# ['There are', 184, 'macro-units after', 12, 'times of renormalization']
# ['The', 12, 'time of renormalization costs-', 0.22936010360717773]
# ['KNN search costs-', 0.000997781753540039]
# ['There are', 183, 'macro-units after', 13, 'times of renormalization']
# ['The', 13, 'time of renormalization costs-', 0.1845078468322754]
# ['KNN search costs-', 0.0019390583038330078]
# ['There are', 177, 'macro-units after', 14, 'times of renormalization']
# ['The', 14, 'time of renormalization costs-', 0.2513294219970703]
# ['KNN search costs-', 0.0009975433349609375]
# ['There are', 175, 'macro-units after', 15, 'times of renormalization']
# ['The', 15, 'time of renormalization costs-', 0.1884899139404297]
# ['KNN search costs-', 0.0009713172912597656]
# ['There are', 173, 'macro-units after', 16, 'times of renormalization']
# ['The', 16, 'time of renormalization costs-', 0.1830577850341797]
# ['KNN search costs-', 0.0010104179382324219]
# ['There are', 170, 'macro-units after', 17, 'times of renormalization']
# ['The', 17, 'time of renormalization costs-', 0.18515491485595703]
# ['KNN search costs-', 0.0009937286376953125]
# ['There are', 170, 'macro-units after', 18, 'times of renormalization']
# ['The', 18, 'time of renormalization costs-', 0.182342529296875]
# ['KNN search costs-', 0.0009970664978027344]
# ['There are', 168, 'macro-units after', 19, 'times of renormalization']
# ['The', 19, 'time of renormalization costs-', 0.2184123992919922]
# ['KNN search costs-', 0.0009701251983642578]
# ['There are', 168, 'macro-units after', 20, 'times of renormalization']
# ['The', 20, 'time of renormalization costs-', 0.1650383472442627]
# ['KNN search costs-', 0.0]
# ['There are', 167, 'macro-units after', 21, 'times of renormalization']
# ['The', 21, 'time of renormalization costs-', 0.19049358367919922]
# ['KNN search costs-', 0.0]
# ['There are', 166, 'macro-units after', 22, 'times of renormalization']
# ['The', 22, 'time of renormalization costs-', 0.26952242851257324]
# ['KNN search costs-', 0.0]
# ['There are', 165, 'macro-units after', 23, 'times of renormalization']
# ['The', 23, 'time of renormalization costs-', 0.12366461753845215]
# ['KNN search costs-', 0.000997304916381836]
# ['There are', 164, 'macro-units after', 24, 'times of renormalization']
# ['The', 24, 'time of renormalization costs-', 0.1825118064880371]
# ['KNN search costs-', 0.0]
# ['There are', 163, 'macro-units after', 25, 'times of renormalization']
# ['The', 25, 'time of renormalization costs-', 0.1426239013671875]
# ['KNN search costs-', 0.0]
# ['There are', 162, 'macro-units after', 26, 'times of renormalization']
# ['The', 26, 'time of renormalization costs-', 0.20146989822387695]
# ['KNN search costs-', 0.0]
# ['There are', 158, 'macro-units after', 27, 'times of renormalization']
# ['The', 27, 'time of renormalization costs-', 0.14659953117370605]
# ['KNN search costs-', 0.0]
# ['There are', 157, 'macro-units after', 28, 'times of renormalization']
# ['The', 28, 'time of renormalization costs-', 0.17617082595825195]
# ['KNN search costs-', 0.000997781753540039]
# ['There are', 156, 'macro-units after', 29, 'times of renormalization']
# ['The', 29, 'time of renormalization costs-', 0.16959428787231445]
# ['KNN search costs-', 0.0]
# ['There are', 155, 'macro-units after', 30, 'times of renormalization']
# ['The', 30, 'time of renormalization costs-', 0.17253971099853516]
# ['KNN search costs-', 0.0]
# ['There are', 155, 'macro-units after', 31, 'times of renormalization']
# ['The', 31, 'time of renormalization costs-', 0.15923070907592773]
# ['KNN search costs-', 0.0]
# ['There are', 154, 'macro-units after', 32, 'times of renormalization']
# ['The', 32, 'time of renormalization costs-', 0.15758061408996582]
# ['KNN search costs-', 0.0]
# ['There are', 154, 'macro-units after', 33, 'times of renormalization']
# ['The', 33, 'time of renormalization costs-', 0.15757226943969727]
# ['KNN search costs-', 0.0]
# ['There are', 153, 'macro-units after', 34, 'times of renormalization']
# ['The', 34, 'time of renormalization costs-', 0.18204689025878906]
# ['KNN search costs-', 0.0010409355163574219]
# ['There are', 152, 'macro-units after', 35, 'times of renormalization']
# ['The', 35, 'time of renormalization costs-', 0.16400694847106934]
# ['KNN search costs-', 0.0]
# ['There are', 152, 'macro-units after', 36, 'times of renormalization']
# ['The', 36, 'time of renormalization costs-', 0.17054104804992676]
# ['KNN search costs-', 0.0]
# ['There are', 150, 'macro-units after', 37, 'times of renormalization']
# ['The', 37, 'time of renormalization costs-', 0.16057062149047852]
# ['KNN search costs-', 0.0]
# ['There are', 149, 'macro-units after', 38, 'times of renormalization']
# ['The', 38, 'time of renormalization costs-', 0.14162135124206543]
# ['KNN search costs-', 0.0009987354278564453]
# ['There are', 148, 'macro-units after', 39, 'times of renormalization']
# ['The', 39, 'time of renormalization costs-', 0.16057038307189941]
# ['KNN search costs-', 0.0009975433349609375]
# ['There are', 147, 'macro-units after', 40, 'times of renormalization']
# ['The', 40, 'time of renormalization costs-', 0.16529297828674316]
# ['KNN search costs-', 0.0010080337524414062]
# ['There are', 144, 'macro-units after', 41, 'times of renormalization']
# ['The', 41, 'time of renormalization costs-', 0.15512442588806152]
# ['KNN search costs-', 0.0]
# ['There are', 143, 'macro-units after', 42, 'times of renormalization']
# ['The', 42, 'time of renormalization costs-', 0.13364291191101074]
# ['KNN search costs-', 0.0]
# ['There are', 140, 'macro-units after', 43, 'times of renormalization']
# ['The', 43, 'time of renormalization costs-', 0.1825122833251953]
# ['KNN search costs-', 0.0]
# ['There are', 136, 'macro-units after', 44, 'times of renormalization']
# ['The', 44, 'time of renormalization costs-', 0.1326448917388916]
# ['KNN search costs-', 0.0009982585906982422]
# ['There are', 134, 'macro-units after', 45, 'times of renormalization']
# ['The', 45, 'time of renormalization costs-', 0.15059757232666016]
# ['KNN search costs-', 0.0]
# ['There are', 132, 'macro-units after', 46, 'times of renormalization']
# ['The', 46, 'time of renormalization costs-', 0.15459513664245605]
# ['KNN search costs-', 0.0]
# ['There are', 132, 'macro-units after', 47, 'times of renormalization']
# ['The', 47, 'time of renormalization costs-', 0.19376540184020996]
# ['KNN search costs-', 0.0]
# ['There are', 130, 'macro-units after', 48, 'times of renormalization']
# ['The', 48, 'time of renormalization costs-', 0.15059471130371094]
# ['KNN search costs-', 0.0]
# ['There are', 127, 'macro-units after', 49, 'times of renormalization']
# ['The', 49, 'time of renormalization costs-', 0.1456136703491211]
# ['KNN search costs-', 0.0]
# ['There are', 123, 'macro-units after', 50, 'times of renormalization']
# ['The', 50, 'time of renormalization costs-', 0.1625669002532959]
# ['KNN search costs-', 0.0]
# ['There are', 120, 'macro-units after', 51, 'times of renormalization']
# ['The', 51, 'time of renormalization costs-', 0.1620628833770752]
# ['KNN search costs-', 0.0]
# ['There are', 118, 'macro-units after', 52, 'times of renormalization']
# ['The', 52, 'time of renormalization costs-', 0.1326439380645752]
# ['KNN search costs-', 0.0009975433349609375]
# ['There are', 115, 'macro-units after', 53, 'times of renormalization']
# ['The', 53, 'time of renormalization costs-', 0.13418316841125488]
# ['KNN search costs-', 0.0]
# ['There are', 114, 'macro-units after', 54, 'times of renormalization']
# ['The', 54, 'time of renormalization costs-', 0.14534974098205566]
# ['KNN search costs-', 0.0]
# ['There are', 112, 'macro-units after', 55, 'times of renormalization']
# ['The', 55, 'time of renormalization costs-', 0.1406242847442627]
# ['KNN search costs-', 0.0]
# ['There are', 108, 'macro-units after', 56, 'times of renormalization']
# ['The', 56, 'time of renormalization costs-', 0.13663244247436523]
# ['KNN search costs-', 0.0]
# ['There are', 106, 'macro-units after', 57, 'times of renormalization']
# ['The', 57, 'time of renormalization costs-', 0.15159058570861816]
# ['KNN search costs-', 0.0]
# ['There are', 105, 'macro-units after', 58, 'times of renormalization']
# ['The', 58, 'time of renormalization costs-', 0.13164973258972168]
# ['KNN search costs-', 0.0009975433349609375]
# ['There are', 103, 'macro-units after', 59, 'times of renormalization']
# ['The', 59, 'time of renormalization costs-', 0.15558266639709473]
# ['KNN search costs-', 0.0]
# ['There are', 103, 'macro-units after', 60, 'times of renormalization']
# ['The', 60, 'time of renormalization costs-', 0.13020086288452148]
# ['KNN search costs-', 0.0]
# ['There are', 102, 'macro-units after', 61, 'times of renormalization']
# ['The', 61, 'time of renormalization costs-', 0.1451561450958252]
# ['KNN search costs-', 0.0]
# ['There are', 100, 'macro-units after', 62, 'times of renormalization']
# ['The', 62, 'time of renormalization costs-', 0.19946742057800293]
# ['KNN search costs-', 0.0]
# ['There are', 100, 'macro-units after', 63, 'times of renormalization']
# ['The', 63, 'time of renormalization costs-', 0.21342706680297852]
# ['KNN search costs-', 0.0]
# ['There are', 98, 'macro-units after', 64, 'times of renormalization']
# ['The', 64, 'time of renormalization costs-', 0.1386265754699707]
# ['KNN search costs-', 0.0]
# ['There are', 95, 'macro-units after', 65, 'times of renormalization']
# ['The', 65, 'time of renormalization costs-', 0.13962650299072266]
# ['KNN search costs-', 0.0009975433349609375]
# ['There are', 95, 'macro-units after', 66, 'times of renormalization']
# ['The', 66, 'time of renormalization costs-', 0.14524316787719727]
# ['KNN search costs-', 0.0]
# ['There are', 92, 'macro-units after', 67, 'times of renormalization']
# ['The', 67, 'time of renormalization costs-', 0.14215373992919922]
# ['KNN search costs-', 0.0]
# ['There are', 87, 'macro-units after', 68, 'times of renormalization']
# ['The', 68, 'time of renormalization costs-', 0.14760422706604004]
# ['KNN search costs-', 0.0]
# ['There are', 87, 'macro-units after', 69, 'times of renormalization']
# ['The', 69, 'time of renormalization costs-', 0.13463926315307617]
# ['KNN search costs-', 0.0009984970092773438]
# ['There are', 85, 'macro-units after', 70, 'times of renormalization']
# ['The', 70, 'time of renormalization costs-', 0.11269903182983398]
# ['KNN search costs-', 0.0]
# ['There are', 83, 'macro-units after', 71, 'times of renormalization']
# ['The', 71, 'time of renormalization costs-', 0.12965679168701172]
# ['KNN search costs-', 0.0]
# ['There are', 83, 'macro-units after', 72, 'times of renormalization']
# ['The', 72, 'time of renormalization costs-', 0.11968183517456055]
# ['KNN search costs-', 0.0]
# ['There are', 81, 'macro-units after', 73, 'times of renormalization']
# ['The', 73, 'time of renormalization costs-', 0.10771012306213379]
# ['KNN search costs-', 0.0]
# ['There are', 79, 'macro-units after', 74, 'times of renormalization']
# ['The', 74, 'time of renormalization costs-', 0.16219353675842285]
# ['KNN search costs-', 0.0]
# ['There are', 76, 'macro-units after', 75, 'times of renormalization']
# ['The', 75, 'time of renormalization costs-', 0.11222457885742188]
# ['KNN search costs-', 0.0]
# ['There are', 74, 'macro-units after', 76, 'times of renormalization']
# ['The', 76, 'time of renormalization costs-', 0.12167239189147949]
# ['KNN search costs-', 0.0]
# ['There are', 74, 'macro-units after', 77, 'times of renormalization']
# ['The', 77, 'time of renormalization costs-', 0.12267518043518066]
# ['KNN search costs-', 0.0]
# ['There are', 73, 'macro-units after', 78, 'times of renormalization']
# ['The', 78, 'time of renormalization costs-', 0.12766146659851074]
# ['KNN search costs-', 0.0]
# ['There are', 69, 'macro-units after', 79, 'times of renormalization']
# ['The', 79, 'time of renormalization costs-', 0.12665843963623047]
# ['KNN search costs-', 0.0]
# ['There are', 69, 'macro-units after', 80, 'times of renormalization']
# ['The', 80, 'time of renormalization costs-', 0.12765908241271973]
# ['KNN search costs-', 0.0]
# ['There are', 67, 'macro-units after', 81, 'times of renormalization']
# ['The', 81, 'time of renormalization costs-', 0.14561223983764648]
# ['KNN search costs-', 0.0009949207305908203]
# ['There are', 66, 'macro-units after', 82, 'times of renormalization']
# ['The', 82, 'time of renormalization costs-', 0.14706659317016602]
# ['KNN search costs-', 0.0]
# ['There are', 65, 'macro-units after', 83, 'times of renormalization']
# ['The', 83, 'time of renormalization costs-', 0.11669278144836426]
# ['KNN search costs-', 0.0009965896606445312]
# ['There are', 60, 'macro-units after', 84, 'times of renormalization']
# ['The', 84, 'time of renormalization costs-', 0.1495974063873291]
# ['KNN search costs-', 0.0]
# ['There are', 58, 'macro-units after', 85, 'times of renormalization']
# ['The', 85, 'time of renormalization costs-', 0.09873604774475098]
# ['KNN search costs-', 0.0]
# ['There are', 56, 'macro-units after', 86, 'times of renormalization']
# ['The', 86, 'time of renormalization costs-', 0.11170697212219238]
# ['KNN search costs-', 0.0]
# ['There are', 56, 'macro-units after', 87, 'times of renormalization']
# ['The', 87, 'time of renormalization costs-', 0.13727045059204102]
# ['KNN search costs-', 0.0]
# ['There are', 56, 'macro-units after', 88, 'times of renormalization']
# ['The', 88, 'time of renormalization costs-', 0.10572242736816406]
# ['KNN search costs-', 0.0]
# ['There are', 56, 'macro-units after', 89, 'times of renormalization']
# ['The', 89, 'time of renormalization costs-', 0.11070418357849121]
# ['KNN search costs-', 0.0]
# ['There are', 55, 'macro-units after', 90, 'times of renormalization']
# ['The', 90, 'time of renormalization costs-', 0.10129046440124512]
# ['KNN search costs-', 0.0]
# ['There are', 54, 'macro-units after', 91, 'times of renormalization']
# ['The', 91, 'time of renormalization costs-', 0.11674094200134277]
# ['KNN search costs-', 0.0]
# ['There are', 53, 'macro-units after', 92, 'times of renormalization']
# ['The', 92, 'time of renormalization costs-', 0.13463926315307617]
# ['KNN search costs-', 0.0]
# ['There are', 52, 'macro-units after', 93, 'times of renormalization']
# ['The', 93, 'time of renormalization costs-', 0.11669206619262695]
# ['KNN search costs-', 0.0]
# ['There are', 50, 'macro-units after', 94, 'times of renormalization']
# ['The', 94, 'time of renormalization costs-', 0.09972953796386719]
# ['KNN search costs-', 0.0]
# ['There are', 49, 'macro-units after', 95, 'times of renormalization']
# ['The', 95, 'time of renormalization costs-', 0.12965822219848633]
# ['KNN search costs-', 0.0]
# ['There are', 49, 'macro-units after', 96, 'times of renormalization']
# ['The', 96, 'time of renormalization costs-', 0.10770702362060547]
# ['KNN search costs-', 0.0]
# ['There are', 47, 'macro-units after', 97, 'times of renormalization']
# ['The', 97, 'time of renormalization costs-', 0.12965798377990723]
# ['KNN search costs-', 0.0]
# ['There are', 44, 'macro-units after', 98, 'times of renormalization']
# ['The', 98, 'time of renormalization costs-', 0.10272049903869629]
# ['KNN search costs-', 0.000997781753540039]
# ['There are', 44, 'macro-units after', 99, 'times of renormalization']
# ['The', 99, 'time of renormalization costs-', 0.09530901908874512]
# ['KNN search costs-', 0.0]
# ['There are', 44, 'macro-units after', 100, 'times of renormalization']
# ['The', 100, 'time of renormalization costs-', 0.13128948211669922]

# %%
Cut_Off_Ratio=0.1
Normalized_activity=Normalized_Dynamics(RG_Flow,Tracked_ID_list,Cut_Off_Ratio)

MeanClusterSize, MeanVar, Coeff, Alpha, R2, MSE, Esti_Alpha_Scaling = Alpha_Scaling(RG_Flow,Tracked_ID_list)

MeanClusterSize, FreeEV, Coeff, Beta, R2, MSE, Esti_Beta_Scaling = Beta_Scaling(RG_Flow,Tracked_ID_list)

Average_Rank_K, Average_Evals, Coeff, Mu, R2, MSE, Esti_Mu_Scaling = Mu_Scaling(RG_Flow,Tracked_ID_list)

ScaledT, MeanACFs, MeanClusterSize, Tau, Coeff, Theta, R2, MSE, Esti_Theta_Scaling = Theta_Scaling(RG_Flow,Tracked_ID_list)
